# %% [markdown]
# ## 1. Research about the Spectral Clustering method, and answer the following questions:
# - Spectral clustering considers data points as nodes in a graph, transforming the problem into a graph partitioning task. These nodes are subsequently projected onto a low-dimensional space, facilitating the formation of clusters. Spectral clustering does not impose any assumptions regarding the shape or form of the clusters. Its objective is to cluster connected data, it makes no assumptions about the form of the clusters. Clustering techniques, like K-Means, assume that the points assigned to a cluster are spherical about the cluster centre.
#
# a. In which cases might it be more useful to apply?
# - spectral clustering is a technique based on graph theory, the approach is used to identify communities of vertices in a graph based on the edges connecting them and has it application in many areas which includes: image segmentation, educational data mining, entity resolution, speech separation, spectral clustering of protein sequences, text image segmentation
#
# b. What are the mathematical fundamentals of it?
#
# - Graph Laplacian:
#
# Spectral clustering involves working with the Laplacian matrix of the similarity graph. The Laplacian matrix is derived from the adjacency matrix of the graph and provides insights into the connectivity and structure of the dat
#
# - Eigenvectors and eigenvalues Decomposition:
#
# Spectral clustering involves computing the eigenvectors and eigenvalues of the Laplacian matrix. These eigenvectors capture the underlying structure of the dat
#
# - Low-Dimensional Representation:
#
# Spectral clustering transforms the data into a lower-dimensional space using the eigenvectors. The first few eigenvectors associated with the smallest eigenvalues are used to represent the data in a reduced dimensionalit
#
# c. What is the algorithm to compute it?
#
# The major steps involved in spectral clustering are: constructing a similarity graph, projecting data onto a lower-dimensional space, and clustering the data. Given a set of points S in a higher-dimensional space, it can be elaborated as follows:
#
# 1. Form a distance matrix
#
# 2. Transform the distance matrix into an affinity matrix A
#
# 3. Compute the degree matrix D and the Laplacian matrix L = D – A.
#
# 4. Find the eigenvalues and eigenvectors of L.
#
# 5. With the eigenvectors of k largest eigenvalues computed from the previous step form a matrix.
#
# 6. Normalize the vectors.
#
# 7. Cluster the data points in k-dimensional space.
#
# d. Does it hold any relation to some of the concepts previously mentioned in class? Which, and how?
#
# - Eigenvalue decomposition is a key step in spectral clustering. The eigenvectors and eigenvalues of the Laplacian matrix provide a basis for the lower-dimensional representation used in clustering.
#
# - Spectral clustering can be seen as an extension of traditional clustering methods like k-means. It offers a more flexible approach, especially when dealing with complex structures in the data.y.a.a.

# %% [markdown]
# ## 2. Research about the DBSCAN method, and answer the following questions:
#
# DBSCAN stands for Density-Based Spatial Clustering of Applications with Noise and works by partitioning the data into dense regions of points that are separated by less dense areas. It defines clusters as areas of the dataset where there are many points close to each other, while the points that are far from any cluster are considered outliers or noise.
#
# a. In which cases might it be more useful to apply?
#
# - Suppose an e-commerce company aims to enhance its sales by recommending pertinent products to customers. The company does not possess precise information about what customers are seeking. However, leveraging a dataset, the company can predict and suggest relevant products to individual customers. The application of DBSCAN to the dataset, derived from the e-commerce database, helps identify clusters based on the products purchased by users. Utilizing these clusters enables the identification of similarities between customers. For instance, if Customer A has purchased 1 pen, 1 book, and 1 pair of scissors, and Customer B has bought 1 book and 1 pair of scissors, the system can recommend 1 pen to Customer B.
#
# - Urban water supply networks constitute a significant concealed underground asset. The clustering of pipe ruptures and bursting can indicate potential issues. Utilizing the Density-based Clustering tool, an engineer can identify these clusters and proactively address high-danger zones within water supply networks.
#
# - If an individual possesses position data for all successful and unsuccessful shots for NBA players, the Density-based Clustering tool can reveal distinct patterns in successful versus failed shot positions for each player. This data can then be utilized to shape game strategy.
#
# - In the case of studying a specific pest-borne disease with a point dataset representing households in the study area, some infested and some not, the Density-based Clustering tool can be employed to identify the largest clusters of infested households. This information helps pinpoint areas to initiate treatment and pest extermination.
#
#
# b. What are the mathematical fundamentals of it?
#
# 1. Core Points, Border Points, and Noise:
#
# -
# DBSCAN defines three types of points - core points, which have a sufficient number of neighbors within a specified radius; border points, which have fewer neighbors but are reachable from a core point; and noise points, which are neither core nor border point
#
# 2. Epsilon (ε) and MinPts:
#
# -
# Parameters in DBSCAN include ε (epsilon), which defines the radius around each point, and MinPts, the minimum number of points within ε to consider a point a core point
#
# 3. Reachability and Connectivity:
#
# DBSCAN determines clusters based on reachability and connectivity. A point is reachable from another if there is a path of core points between the
#
# c. Is there any relation between DBSCAN and Spectral Clustering? If so, what is it?
#
# Density vs. Affinity:
#
# DBSCAN: It is a density-based clustering algorithm that groups together data points that are close to each other in the feature space and have a sufficient number of neighbors within a specified distance.
#
# Spectral Clustering: It is an affinity-based clustering algorithm that relies on the similarity (affinity) between data points. Spectral clustering transforms the data into a higher-dimensional space and then performs clustering in this transformed space based on affinity.
#
# Handling Arbitrary-Shaped Clusters:
#
# DBSCAN: It is capable of finding clusters of arbitrary shapes and is less sensitive to the shape of cluster
# s.
# Spectral Clustering: It may struggle with non-convex or irregularly shaped clusters, as it operates based on the affinity mat
#
# In conclusion:
# "Spectral clustering is as good as DBSCAN, and both algorithms can be replaced with each other to avoid their own disadvantages."
# Y. Chen, "DBSCAN Is Semi-Spectral Clustering," 2020 6th International Conference on Big Data and Information Analytics (BigDIA), Shenzhen, China, 2020, pp. 257-264, doi: 10.1109/BigDIA51454.2020.00048. keywords: {Laplace equations;Clustering methods;Clustering algorithms;Eigenvalues and eigenfunctions;Matrix converters;Task analysis;Optimization;spectral clustering;dbscan;graph cut;∊-neighborhood graph},
#
# rix..
#
# s.

# %% [markdown]
# ## 3. What is the elbow method in clustering? And which flaws does it pose to assess quality?
#
# The elbow method is a graphical methode used in clustering analysis to find the optimal number of clusters for a dataset. It involves running a clustering algorithm with different values of k (number of clusters) and plotting the variance or some other measure of compactness against the number of clusters. The "elbow" of the resulting plot is considered to be the point at which adding more clusters does not significantly improve the quality of the clustering.
#
# Elbow Method Drawbacks:
#
# - Subjectivity: The choice of the “elbow point” can be subjective and might vary between individuals analyzing the same data.
# - Non-Gaussian Data: It assumes that clusters are spherical and equally sized, which may not hold for complex datasets with irregularly shaped or differently sized clusters.
# - Sensitivity to Initialization: K-means itself is sensitive to initial cluster centroids, which can affect the  within-cluster-sum-of-square (WCSS)  values and, consequently, the choice of the optimal K.
# - Inefficient for Large Datasets: For large datasets, calculating WCSS for a range of K values can be computationally expensive and time-consuming.
# - Unsuitable for All Distributions: The elbow method is not suitable for all data distributions, especially when clusters have varying densities or are non-convex.
# - Limited to K-means: It specifically applies to K-means clustering and may not be suitable for other clustering algorithms with different objectives.
# ives.

# %% [markdown]
# ## 5

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

from sklearn.datasets import make_blobs
X, y = make_blobs(
n_samples=500,
n_features=2,
centers=4,
cluster_std=1,
center_box=(-10.0, 10.0),
shuffle=True,
random_state=1,
)

# %%
plt.title("Unclustered Data")
plt.scatter(X[:, 0], X[:, 1], s=15)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# Instantiate and fit KMeans
kmeans = KMeans_SCRATH(n_clusters=4)
kmeans.fit(X)

# Plot the dataset and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=kmeans._assign_labels(X), cmap='viridis')
plt.title('KMeans Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# The graph shows 4 clusters, 3 of them are quite close to each other while one of them is far away in the upper right part.

# %%
from sklearn.metrics import silhouette_score
def calculate_silhouette(X, algorithm, max_clusters):
    silhouette_scores = []

    for k in range(2, max_clusters + 1):
        if algorithm == 'kmeans':
            model = KMeans_SCRATH(n_clusters=k)
        elif algorithm == 'kmedoids':
            model = KMedoids_SCRATH(n_clusters=k)

        model.fit(X)
        labels = model._assign_labels(X)
        silhouette_scores.append(silhouette_score(X, labels))

    return silhouette_scores

# %%
# Calculate silhouette scores for k-means and k-medoids
max_clusters = 5
kmeans_silhouette_scores = calculate_silhouette(X, 'kmeans', max_clusters)
kmedoids_silhouette_scores = calculate_silhouette(X, 'kmedoids', max_clusters)

# Plot silhouette scores
plt.plot(range(2, max_clusters + 1), kmeans_silhouette_scores, label='KMeans', marker='o')
plt.plot(range(2, max_clusters + 1), kmedoids_silhouette_scores, label='KMedoids', marker='o')
plt.title('Silhouette Scores for KMeans and KMedoids')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.legend()
plt.show()

# %% [markdown]
# - It can be seen that for the Kmeans model, the value of K=2 is where the Silhouette Scores are the highest for Silhouette Scores.
# - for the Kmedoids model the highest value of Silhouette Scores is at K=3.

# %% [markdown]
# # 6

# %%
import numpy as np
from sklearn import cluster, datasets, mixture
# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None


# Anisotropically distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)
# blobs with varied variances
varied = datasets.make_blobs(
n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# %%
# Datasets
datasets = [noisy_circles, noisy_moons, blobs, no_structure, aniso, varied]
dataset_names = ['Noisy Circles', 'Noisy Moons', 'Blobs', 'No Structure', 'Aniso', 'Varied Variances']

# %%
# Plot datasets
plt.figure(figsize=(15, 10))
for i, (dataset, name) in enumerate(zip(datasets, dataset_names), 1):
    X, y = dataset
    plt.subplot(2, 3, i)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k')
    plt.title(name)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN, SpectralClustering
from sklearn_extra.cluster import KMedoids

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, DBSCAN, SpectralClustering
from sklearn_extra.cluster import KMedoids

# Datasets
datasets = [noisy_circles, noisy_moons, blobs, no_structure, aniso, varied]
dataset_names = ['Noisy Circles', 'Noisy Moons', 'Blobs', 'No Structure', 'Aniso', 'Varied Variances']

# Algorithms
algorithms = {
    'KMeans': KMeans(n_clusters=3),
    'KMedoids': KMedoids(n_clusters=3),
    'DBSCAN': DBSCAN(eps=0.2, min_samples=5),
    'Spectral Clustering': SpectralClustering(n_clusters=3, affinity='nearest_neighbors')
}

# Plot datasets and clustering results
for i, (dataset, name) in enumerate(zip(datasets, dataset_names), 1):
    X, y = dataset

    # Plot original dataset
    plt.figure(figsize=(15, 4))
    plt.subplot(1, len(algorithms) + 1, 1)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolors='k')
    plt.title(f'{name} - True Labels')

    # Apply clustering algorithms and plot results
    for j, (algo_name, algo) in enumerate(algorithms.items(), 2):
        plt.subplot(1, len(algorithms) + 1, j)
        algo.fit(X)
        labels = algo.labels_
        plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolors='k', alpha=0.5)
        plt.title(f'{name} - {algo_name}')

    plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# C:\Users\user\AppData\Local\Temp\ipykernel_10316\3804385160.py:24: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolors='k')
